# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Table Creation

# %%
writer = pd.ExcelWriter("../data/Pivot_Tables.xlsx",engine='xlsxwriter')

# %%
data = pd.read_csv("../data/CleanedData.csv",index_col='Unnamed: 0')
data.head()
# Out:
#    Year    Month   Country_of_origin  Imports_hardcoal_tonnes  \
# 0  2004  January        EU countries                   3280.0
# 1  2004  January     Third countries                3586305.0
# 2  2004  January      United Kingdom                      0.0
# 3  2004  January  Russian Federation                 301727.0
# 4  2004  January        South Africa                1059709.0
#
#    Imports_hardcoal_gigajoules  Average_calorificvalue_hardcoal  \
# 0                      61556.0                          18767.0
# 1                   95536615.0                          26639.0
# 2                          0.0                              0.0
# 3                    7822842.0                          25927.0
# 4                   26718972.0                          25213.0
#
#    Imports_hardcoal_euros  Imports_hardcoal_eurospert  \
# 0                116541.0                       35.53
# 1             150263584.0                       41.90
# ...

# %%
pivot_table_year = pd.pivot_table(
    data,
    index="Year",
    values=["Imports_hardcoal_tonnes","Imports_hardcoal_euros","Imports_hardcoal_eurospert"],
    aggfunc={
        "Imports_hardcoal_tonnes":np.mean,
        "Imports_hardcoal_euros":np.mean,
        "Imports_hardcoal_eurospert":np.mean
    }
)
pivot_table_year.to_excel(writer,sheet_name="Year")
pivot_table_year

# %%
pivot_table_month = pd.pivot_table(
    data,
    index="Month",
    values=["Imports_hardcoal_tonnes","Imports_hardcoal_euros","Imports_hardcoal_eurospert"],
    aggfunc={
        "Imports_hardcoal_tonnes":np.mean,
        "Imports_hardcoal_euros":np.mean,
        "Imports_hardcoal_eurospert":np.mean
    }
).reindex(["January","February","March","April","May","June","July","August","September","October","November","December"])
pivot_table_month.to_excel(writer,sheet_name="Month")
pivot_table_month

# %%
pivot_table_coo2 = pd.pivot_table(
    data,
    index="Country_of_origin",
    values=["Imports_hardcoal_tonnes","Imports_hardcoal_euros","Imports_hardcoal_eurospert"],
    aggfunc={
        "Imports_hardcoal_tonnes":np.sum,
        "Imports_hardcoal_euros":np.sum,
        "Imports_hardcoal_eurospert":np.sum
    }
)

# %%
pivot_table_coo = pd.pivot_table(
    data,
    index="Country_of_origin",
    values=["Imports_hardcoal_tonnes","Imports_hardcoal_euros","Imports_hardcoal_eurospert"],
    aggfunc={
        "Imports_hardcoal_tonnes":np.mean,
        "Imports_hardcoal_euros":np.mean,
        "Imports_hardcoal_eurospert":np.mean
    }
)
pivot_table_coo.to_excel(writer,sheet_name="Country of Origin")
pivot_table_coo
# Out:
#                        Imports_hardcoal_euros  Imports_hardcoal_eurospert  \
# Country_of_origin
# Australia                        6.536412e+07                  154.357297
# Canada                           1.794892e+07                  141.155000
# Colombia                         3.752523e+07                   80.515746
# EU countries                     2.623988e+07                   94.076623
# Other third countries            1.183440e+07                   95.850217
# Russian Federation               8.910497e+07                   88.416579
# South Africa                     2.752018e+07                   70.719152
# Third countries                  2.988370e+08                  102.601053
# United Kingdom                   0.000000e+00                    0.000000
# United States                    6.480925e+07                  117.218079
#
#                        Imports_hardcoal_tonnes
# Country_of_origin
# Australia                         4.175936e+05
# ...

# %%
writer.close()
# Out:
# /home/kshitij/.local/lib/python3.8/site-packages/xlsxwriter/workbook.py:339: UserWarning: Calling close() on already closed file.
#   warn("Calling close() on already closed file.")

# %%
data04_08 = data[data.Year.between(2004,2008)]
data09_13 = data[data.Year.between(2009,2013)]
data14_18 = data[data.Year.between(2014,2018)]
data19_22 = data[data.Year.between(2019,2022)]

# %%
pivot_table_month0408 = pd.pivot_table(
    data04_08,
    index="Month",
    values=["Imports_hardcoal_tonnes","Imports_hardcoal_euros","Imports_hardcoal_eurospert"],
    aggfunc={
        "Imports_hardcoal_tonnes":np.mean,
        "Imports_hardcoal_euros":np.mean,
        "Imports_hardcoal_eurospert":np.mean
    }
).reindex(["January","February","March","April","May","June","July","August","September","October","November","December"])
# pivot_table_month
pivot_table_month0913 = pd.pivot_table(
    data09_13,
    index="Month",
    values=["Imports_hardcoal_tonnes","Imports_hardcoal_euros","Imports_hardcoal_eurospert"],
    aggfunc={
        "Imports_hardcoal_tonnes":np.mean,
        "Imports_hardcoal_euros":np.mean,
        "Imports_hardcoal_eurospert":np.mean
    }
).reindex(["January","February","March","April","May","June","July","August","September","October","November","December"])
# pivot_table_month
pivot_table_month1418 = pd.pivot_table(
    data14_18,
    index="Month",
    values=["Imports_hardcoal_tonnes","Imports_hardcoal_euros","Imports_hardcoal_eurospert"],
    aggfunc={
        "Imports_hardcoal_tonnes":np.mean,
        "Imports_hardcoal_euros":np.mean,
        "Imports_hardcoal_eurospert":np.mean
    }
).reindex(["January","February","March","April","May","June","July","August","September","October","November","December"])
# pivot_table_month
pivot_table_month1922 = pd.pivot_table(
    data19_22,
    index="Month",
    values=["Imports_hardcoal_tonnes","Imports_hardcoal_euros","Imports_hardcoal_eurospert"],
    aggfunc={
        "Imports_hardcoal_tonnes":np.mean,
        "Imports_hardcoal_euros":np.mean,
        "Imports_hardcoal_eurospert":np.mean
    }
).reindex(["January","February","March","April","May","June","July","August","September","October","November","December"])
# pivot_table_month

# %%
mean_imports_tonnes_pm = []
for i,j,k,l in zip(pivot_table_month0408['Imports_hardcoal_tonnes'],pivot_table_month0913['Imports_hardcoal_tonnes'],pivot_table_month1418['Imports_hardcoal_tonnes'],pivot_table_month1922['Imports_hardcoal_tonnes']):
    mean_imports_tonnes_pm.append(np.mean([i,j,k,l]))

# %%
missing_data_avg = data[data.Year != 2020]["Imports_hardcoal_tonnes"].isna().value_counts()
print(f"Average missing values in the data: {np.round(np.round(missing_data_avg.iloc[1]/(missing_data_avg.iloc[0]+missing_data_avg.iloc[1]),5)*100,3)} %")
# Out:
# Average missing values in the data: 13.704 %

# %%
missing_data_2020 = data[data.Year == 2020]["Imports_hardcoal_tonnes"].isna().value_counts()
print(f"Percent missing values in the 2020 data: {np.round(np.round(missing_data_2020.iloc[1]/(missing_data_2020.iloc[0]+missing_data_2020.iloc[1]),5)*100,3)} %")
# Out:
# Percent missing values in the 2020 data: 28.333 %

# %%
bool_list = list((data[data.Year == 2020]["Imports_hardcoal_tonnes"].isnull()) | (data[data.Year == 2020]["Imports_hardcoal_tonnes"].isna()))

# %%
pivot_table_year2 = pivot_table_year.copy()

# %%
len(pivot_table_year.Imports_hardcoal_tonnes)
# Out:
# 19

# %%
len(np.convolve(pivot_table_year.Imports_hardcoal_tonnes,[0.25,0.25,0.25,0.25],mode="same"))
# Out:
# 19

# %%
pivot_table_year["Imports_hardcoal_tonnes_MA3y"] = np.convolve(pivot_table_year.Imports_hardcoal_tonnes,[1/3,1/3,1/3],mode="same")
pivot_table_year.head()
# Out:
#       Imports_hardcoal_euros  Imports_hardcoal_eurospert  \
# Year
# 2004            3.560207e+07                   47.007917
# 2005            4.150519e+07                   57.596875
# 2006            4.295571e+07                   68.682083
# 2007            4.563817e+07                   65.256525
# 2008            7.018092e+07                   93.462456
#
#       Imports_hardcoal_tonnes  Imports_hardcoal_tonnes_MA3y
# Year
# 2004            679572.125000                 439017.399306
# 2005            637480.072917                 647293.674306
# 2006            624828.825000                 639898.723034
# 2007            657387.271186                 653408.587618
# 2008            678009.666667                 642464.429577

# %%
print(f"Percent import from Third Countries: {np.round(pivot_table_coo.Imports_hardcoal_tonnes.loc['Third countries'] / sum(pivot_table_coo.Imports_hardcoal_tonnes) * 100,2)}%")
print(f"Percent import from Russian Federation: {np.round(pivot_table_coo.Imports_hardcoal_tonnes.loc['Russian Federation'] / sum(pivot_table_coo.Imports_hardcoal_tonnes) * 100,2)}%")
print(f"Percent import from Australia: {np.round(pivot_table_coo.Imports_hardcoal_tonnes.loc['Australia'] / sum(pivot_table_coo.Imports_hardcoal_tonnes) * 100,2)}%")
print(f"Percent import from Canada: {np.round(pivot_table_coo.Imports_hardcoal_tonnes.loc['Canada'] / sum(pivot_table_coo.Imports_hardcoal_tonnes) * 100,2)}%")
print(f"Percent import from Third Countries Euros: {np.round(pivot_table_coo.Imports_hardcoal_euros.loc['Third countries'] / sum(pivot_table_coo.Imports_hardcoal_euros) * 100,2)}%")
print(f"Percent import from Australia Euros: {np.round(pivot_table_coo.Imports_hardcoal_euros.loc['Australia'] / sum(pivot_table_coo.Imports_hardcoal_euros) * 100,2)}%")
print(f"Percent import from Russian Federation Euros: {np.round(pivot_table_coo.Imports_hardcoal_euros.loc['Russian Federation'] / sum(pivot_table_coo.Imports_hardcoal_euros) * 100,2)}%")
# Out:
# Percent import from Third Countries: 45.75%
# Percent import from Russian Federation: 15.65%
# Percent import from Australia: 6.55%
# Percent import from Canada: 2.01%
# Percent import from Third Countries Euros: 46.75%
# Percent import from Australia Euros: 10.23%
# Percent import from Russian Federation Euros: 13.94%

# %%
pivot_table_coo.Imports_hardcoal_eurospert.loc["Canada"]
# Out:
# 141.155

# %%
y = list(pivot_table_year.Imports_hardcoal_tonnes_MA3y.loc[[2010,2011,2012,2013,2014,2015]])
per_diff = []
for i in range(len(y)-1):
    per_diff.append(np.round((y[i+1] - y[i])*100/y[i],2))

print(f"Average Year on Year growth of Coal Imports between 2010 and 2015: {np.mean(per_diff)}%")
# Out:
# Average Year on Year growth of Coal Imports between 2010 and 2015: 4.428%

# %%
y = list(pivot_table_year.Imports_hardcoal_tonnes.loc[[2020,2021,2022]])
per_diff = []
for i in range(len(y)-1):
    per_diff.append(np.round((y[i+1] - y[i])*100/y[i],2))

print(f"Average Year on Year growth of Coal Imports between 2020 and 2022: {np.mean(per_diff)}%")
# Out:
# Average Year on Year growth of Coal Imports between 2020 and 2022: 26.395000000000003%

# %%
y = list(pivot_table_year.Imports_hardcoal_tonnes_MA3y.loc[[2017,2018,2019]])
per_diff = []
for i in range(len(y)-1):
    per_diff.append(np.round((y[i+1] - y[i])*100/y[i],2))

print(f"Average Year on Year decline of Coal Imports between 2017 and 2019: {np.mean(per_diff)}%")
# Out:
# Average Year on Year decline of Coal Imports between 2017 and 2019: -6.085%

# %%
y = list(pivot_table_year.Imports_hardcoal_eurospert.loc[[2020,2021,2022]])
per_diff = []
for i in range(len(y)-1):
    per_diff.append(np.round((y[i+1] - y[i])*100/y[i],2))

print(f"Average Year on Year growth of Coal Imports between 2020 and 2022: {np.mean(per_diff)}%")
# Out:
# Average Year on Year growth of Coal Imports between 2020 and 2022: 113.785%

# %% [markdown]
# # Visualisations

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
plt.figure(figsize=(8,5))
sns.barplot(
    x=pivot_table_coo["Imports_hardcoal_euros"],
    y=pivot_table_coo.index,
    linewidth=1,
    edgecolor="k"
    ).set(xlabel="Euros",ylabel="Country of Origin")

plt.tight_layout()
plt.savefig("../images/Country_of_Origin_TotalEuros.jpg",dpi=300,edgecolor="k")

# %%
fig,axes = plt.subplots(1,2,figsize=(15,7),sharey=True)

sns.barplot(
    ax = axes[0],
    x=pivot_table_coo["Imports_hardcoal_tonnes"],
    y=pivot_table_coo.index,
    linewidth=1,
    edgecolor="k"
    ).set(xlabel="Tonnes",ylabel="Country of Origin")

sns.barplot(
    ax = axes[1],
    x=pivot_table_coo["Imports_hardcoal_eurospert"],
    y=pivot_table_coo.index,
    linewidth=1,
    edgecolor="k"
).set(xlabel="Euros Per Tonne",ylabel=None)

plt.tight_layout()
plt.savefig("../images/Country_of_Origin_Comparison.jpg",dpi=300,edgecolor='k');

# %%
fig,axes = plt.subplots(1,2,figsize=(15,7),sharey=True)

sns.barplot(
    ax = axes[0],
    x=pivot_table_coo2["Imports_hardcoal_tonnes"],
    y=pivot_table_coo2.index,
    linewidth=1,
    edgecolor="k"
    ).set(xlabel="Tonnes",ylabel="Country of Origin")

sns.barplot(
    ax = axes[1],
    x=pivot_table_coo2["Imports_hardcoal_eurospert"],
    y=pivot_table_coo2.index,
    linewidth=1,
    edgecolor="k"
).set(xlabel="Euros Per Tonne",ylabel=None)

plt.tight_layout()

# %%
fig, axes = plt.subplots(2,1,figsize=(10,15))
sns.lineplot(
    ax = axes[0],
    data=pivot_table_year,
    x = pivot_table_year.index,
    y = "Imports_hardcoal_tonnes",
    linewidth=2,alpha=0.5
)
sns.lineplot(
    ax = axes[0],
    x = pivot_table_year.index[1:-1],
    y = pivot_table_year.Imports_hardcoal_tonnes_MA3y[1:-1],
    linewidth=2,
    linestyle="--",
    alpha=1,
    color="k"
)

sns.lineplot(
    ax = axes[1],
    data = pivot_table_year,
    x = pivot_table_year.index,
    y = "Imports_hardcoal_eurospert"
)
axes[0].legend(["Imports Tonnes","3 Year Moving Average"],loc="best")
axes[0].set_xticks(pivot_table_year.index[::2]);
axes[1].set_xticks(pivot_table_year.index[::2]);
plt.tight_layout()
plt.savefig("../images/Import_hardcoal_yearly.jpg",dpi=300,edgecolor='k');

# %%
fig, axes = plt.subplots(2,1,figsize=(10,15))
sns.lineplot(
    ax = axes[0],
    data=pivot_table_year,
    x = pivot_table_year.index,
    y = "Imports_hardcoal_tonnes",
    linewidth=2,alpha=0.5
)
sns.lineplot(
    ax = axes[0],
    x = pivot_table_year.index[1:-1],
    y = pivot_table_year.Imports_hardcoal_tonnes_MA3y[1:-1],
    linewidth=2,
    linestyle="--",
    alpha=1,
    color="k"
)

sns.lineplot(
    ax = axes[1],
    data = pivot_table_year,
    x = pivot_table_year.index,
    y = "Imports_hardcoal_eurospert"
)
axes[0].legend(["Imports Tonnes","3 Year Moving Average"],loc="best")
axes[0].set_xticks(pivot_table_year.index[::2]);
axes[1].set_xticks(pivot_table_year.index[::2]);
plt.tight_layout()
# plt.savefig("../images/Import_hardcoal_yearly.jpg",dpi=300,edgecolor='k');

# %%
plt.figure(figsize=(10,10))
sns.lineplot(
    data = pivot_table_month0408,
    x = pivot_table_month0408.index,
    y = "Imports_hardcoal_eurospert",
    color = "r",
    linewidth=2
)
sns.lineplot(
    data = pivot_table_month0913,
    x = pivot_table_month0913.index,
    y = "Imports_hardcoal_eurospert",
    color = "y",
    linewidth=2
)
sns.lineplot(
    data = pivot_table_month1418,
    x = pivot_table_month1418.index,
    y = "Imports_hardcoal_eurospert",
    color = "g",
    linewidth=2
)
sns.lineplot(
    data = pivot_table_month1922,
    x = pivot_table_month1922.index,
    y = "Imports_hardcoal_eurospert",
    color = "b",
    linewidth=2
)
plt.xticks(pivot_table_month0408.index,rotation=90);
plt.legend(["2004-2008","2009-2013","2014-2018","2019-2022"],loc="best");
plt.savefig("../images/Imports_hardcoal_eurospert_month.jpg",dpi=300,edgecolor="k");

# %%
plt.figure(figsize=(10,10))
sns.lineplot(
    data = pivot_table_month0408,
    x = pivot_table_month0408.index,
    y = 'Imports_hardcoal_tonnes',
    color = "r",
    linewidth=2,
    alpha=0.5
)
sns.lineplot(
    data = pivot_table_month0913,
    x = pivot_table_month0913.index,
    y = 'Imports_hardcoal_tonnes',
    color = "y",
    linewidth=2,
    alpha=0.5
)
sns.lineplot(
    data = pivot_table_month1418,
    x = pivot_table_month1418.index,
    y = 'Imports_hardcoal_tonnes',
    color = "g",
    linewidth=2,
    alpha=0.5
)
sns.lineplot(
    data = pivot_table_month1922,
    x = pivot_table_month1922.index,
    y = 'Imports_hardcoal_tonnes',
    color = "b",
    linewidth=2,
    alpha=0.5
)
sns.lineplot(
    x = pivot_table_month.index,
    y = mean_imports_tonnes_pm,
    color = "k",
    linewidth=2
)
plt.xticks(pivot_table_month0408.index,rotation=90);
plt.legend(["2004-2008","2009-2013","2014-2018","2019-2022","Average(Tonnes)"],loc="best");
plt.savefig("../images/Imports_hardcoal_tonnes_compared_months.jpg",dpi=300,edgecolor="k");
